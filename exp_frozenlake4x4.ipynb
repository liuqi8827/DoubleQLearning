# %%
# from Games.FrozenLake import FrozenLakeEnv
from Experiments.experiment import experiment
import gym

# %%
discrete_env = gym.make('FrozenLake-v1')
seeds = [1, 2] #Defaults to [0-9]

params = {
'epsilon': 0.001, #Defaults to  0.1
'num_episodes': 10000, #Defaults to 1000
'discount_factor': 1, #Defaults to 1.0
'alpha': 0.8 #Defaults to 0.1
}

experiment('Discrete', discrete_env,  params, seeds)
# Out:
# Starting experiment
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#  50%|█████     | 1/2 [00:26<00:26, 26.23s/it]
#
#
#
#
# 100%|██████████| 2/2 [00:56<00:00, 27.29s/it]

# %%
seeds = [0]
epsilons = [0.1, 0.01, 0.001]
num_episodeses = [2000] # I guess you just make this higher, no need to grid search
discount_factors = [0.7, 0.85, 1.0]
alphas = [0.1, 0.05, 0.01]

def grid_search(env_name, env, epsilons, num_episodeses, discount_factors, alphas, seeds=None, default_dir='Results'):
    params = {}
    for epsilon in epsilons:
        params['epsilon'] = epsilon
        for num_episodes in num_episodeses:
            params['num_episodes'] = num_episodes
            for discount_factor in discount_factors:
                params['discount_factor'] = discount_factor
                for alpha in alphas:
                    params['alpha'] = alpha
                    print(params)
                    experiment(env_name, env, params, seeds=seeds, default_dir=default_dir)
# grid_search("FrozenLakeEnv", discrete_env, epsilons, num_episodeses, discount_factors, alphas, seeds=seeds)
# Out:
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.1}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:17<00:00, 17.33s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.05}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:15<00:00, 15.47s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.01}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:15<00:00, 15.59s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.85, 'alpha': 0.1}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:14<00:00, 14.67s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.85, 'alpha': 0.05}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:14<00:00, 14.78s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 0.85, 'alpha': 0.01}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:14<00:00, 14.83s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 1.0, 'alpha': 0.1}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:14<00:00, 14.50s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 1.0, 'alpha': 0.05}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:15<00:00, 15.18s/it]
# {'epsilon': 0.1, 'num_episodes': 2000, 'discount_factor': 1.0, 'alpha': 0.01}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [00:14<00:00, 14.76s/it]
# {'epsilon': 0.01, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.1}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [02:22<00:00, 142.23s/it]
# {'epsilon': 0.01, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.05}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 1/1 [02:32<00:00, 152.01s/it]
# {'epsilon': 0.01, 'num_episodes': 2000, 'discount_factor': 0.7, 'alpha': 0.01}
# Starting experiment
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1248/3318561072.py in <module>
# ----> 1 grid_search("FrozenLakeEnv", discrete_env, epsilons, num_episodeses, discount_factors, alphas, seeds=seeds)
#
# ~\AppData\Local\Temp/ipykernel_1248/965968443.py in grid_search(env_name, env, epsilons, num_episodeses, discount_factors, alphas, seeds, default_dir)
#      18                     params['alpha'] = alpha
#      19                     print(params)
# ---> 20                     experiment(env_name, env, params, seeds=seeds, default_dir=default_dir)
#      21
#      22
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Experiments\experiment.py in experiment(env_name, env, params, seeds, default_dir)
#      19
#      20     # Get results for test
# ---> 21     single_results, double_results = run_experiment(env, seeds=seeds, params=params)
#      22
#      23     # Save Results to csv
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Experiments\experiment.py in run_experiment(env, seeds, params, show_episodes)
#      53     for i in tqdm(seeds):
#      54         np.random.seed(i)
# ---> 55         single_result, double_result = single_run(env, params=params, show_episodes=show_episodes)
#      56         single_lengths.append(single_result[0])
#      57         single_returns.append(single_result[1])
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Experiments\experiment.py in single_run(env, params, show_episodes)
#      76     single_policy = EpsilonGreedyPolicy(epsilon, Q)
#      77     single_q = SingleQLearning()
# ---> 78     single_q_vals, single_q_results = \
#      79         single_q.train(env, single_policy, num_episodes, discount_factor=discount_factor, alpha=alpha, show_episodes=show_episodes)
#      80
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Experiments\experiment.py in double_q(env, epsilon, num_episodes, discount_factor, alpha, show_episodes)
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Algorithms\q_learning.py in train(self, env, policy, num_episodes, discount_factor, alpha, show_episodes)
#      91
#      92         for i_episode in episode_range:
# ---> 93             i, R = self.sample_episode(env, policy)
#      94             stats.append((i, R))
#      95
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Algorithms\q_learning.py in sample_episode(self, env, policy)
#      49             next_state, reward, done, _ = transition
#      50
# ---> 51             self.update_Q(policy, reward, state, next_state, action)
#      52
#      53             state = next_state
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Algorithms\q_learning.py in update_Q(self, policy, reward, state, next_state, action)
#     137             self.update_double_Q(Q_a, Q_b, reward, state, next_state, action)
#     138         else:
# --> 139             self.update_double_Q(Q_b, Q_a, reward, state, next_state, action)
#     140
#     141
#
# c:\Users\aukee\OneDrive\GitHub\DoubleQLearning\Algorithms\q_learning.py in update_double_Q(self, Q_1, Q_2, reward, state, next_state, action)
#     147         max_action = np.argmax(Q_1.setdefault(next_state, self.new_val(val)))
#     148         Q_1[state][action] = Q_1.setdefault(state, self.new_val(val))[action] + self.alpha * \
# --> 149             (reward + self.discount_factor * Q_2.setdefault(next_state, self.new_val(val))[max_action] - Q_1[state][action])
#     150         return
#     151
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# ~\miniconda3\envs\rl-project\lib\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1186
#    1187     """
# -> 1188     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1189
#    1190
#
# ~\miniconda3\envs\rl-project\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
stochastic_env = FrozenLakeEnv(stochastic=True)
experiment('Stochastic', stochastic_env,  params, seeds)
# Out:
# Starting experiment
# 100%|██████████| 3/3 [00:00<00:00,  7.98it/s]
