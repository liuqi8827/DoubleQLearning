# %%
from Games.random_gridworld import RandomGridworldEnv
from Helper.experiment import experiment
# Out:
# C:\Users\aukee\miniconda3\envs\rl-project\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
epsilon = 0.1
shape = [4, 4] #Default is [4, 4]
final_reward = 0 # Reward upon termination, defaults to 5
seeds = None #Defaults to [0-9] when set to None
params = {
'epsilon': 0.01, #Defaults to  0.1
'num_episodes': 1000, #Defaults to 1000
'discount_factor': 0.95, #Defaults to 1.0
'alpha': 0.01 #Defaults to 0.1
}
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 35442.83it/s]

# %%
env = RandomGridworldEnv(shape, final_reward)
experiment("Random Gridworld", env, params, seeds)
# Out:
# Starting experiment
# 100%|██████████| 10/10 [17:07<00:00, 103.72s/it]

# %%
# Out:
# [[0.0, 0],
#  [-0.14408028858992608, 0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
# ...
