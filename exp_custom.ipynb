# %%
from Algorithms.q_learning import SingleQLearning, DoubleQLearning
from Games.customgame import FirstGame
from Algorithms.policy import EpsilonGreedyPolicy

# %%
num_actions = 5
epsilon = 0.1

env = FirstGame(num_actions)
Q_a = {k:[0 for _ in range(env.nA[k])] for k in [0,1]}
Q_a[2] = [0]
Q_a[3] = [0]
Q_b = {k:[0 for _ in range(env.nA[k])] for k in [0,1]}
Q_b[2] = [0]
Q_b[3] = [0]

policy = EpsilonGreedyPolicy(epsilon, Q_a, None)
single_q = SingleQLearning()
Q, (episode_lengths, episode_returns), Q_values = single_q.train(env, policy, 100)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 35442.83it/s]

# %%
Q_values
# Out:
# [[0.0, 0],
#  [-0.14408028858992608, 0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
#  [-0.14408028858992608, 0.0],
# ...
