# %%
from Algorithms.single_q_learning import SingleQLearning
from Games.customgame import FirstGame
from Experiments.experiment import experiment

# %%
discrete_env = FirstGame(10)

params = {
'epsilon': 0.001, #Defaults to  0.1
'num_episodes': 10, #Defaults to 1000
'discount_factor': 1, #Defaults to 1.0
'alpha': 0.01 #Defaults to 0.1
}
experiment('first', discrete_env,  params, seeds=None)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 750.12it/s]
# Starting experiment

# %%
stochastic_env = CliffWalkingEnv(stochastic=True)
